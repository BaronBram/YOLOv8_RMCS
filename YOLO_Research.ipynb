# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/107.7 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 395, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
model = YOLO('yolov8m-cls.pt')

# %%
# results = model.train(data='mnist160', epochs=100, imgsz=64)
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="g7gXoup7ZFhHXfT0e6Vk")
project = rf.workspace("college-yonms").project("cancer-types")
dataset = project.version(2).download("folder")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Cancer-Types-2 in folder:: 100%|██████████| 862/862 [00:00<00:00, 4881.02it/s]

# %%
# !yolo task=classify mode=train model=yolov8m-cls.pt data={dataset.location} epochs=100 imgsz=64
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo predict model='/content/runs/classify/train/weights/best.pt' source='/content/Cancer-Types-1/test/adenocarcinoma/000108-3-_png.rf.9bd3dabf2c261d9ba78acde74d03e069.jpg'
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m-cls summary (fused): 103 layers, 15767780 parameters, 0 gradients, 41.6 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 448, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 239, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 207, in predict_cli
#     for _ in gen:  # running CLI inference without accumulating any outputs (do not modify)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 35, in generator_context
# ...

# %%
# !yolo predict model='/content/runs/classify/train/weights/best.pt' source='/content/Cancer-Types-1/test/squamous cell carcinoma/000112_png.rf.3ccac1c3ce822de547de5b748aff65da.jpg'
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m-cls summary (fused): 103 layers, 15767780 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /content/Cancer-Types-1/test/squamous cell carcinoma/000112_png.rf.3ccac1c3ce822de547de5b748aff65da.jpg: 64x64 squamous cell carcinoma 0.52, normal 0.46, adenocarcinoma 0.02, large cell carcinoma 0.01, 32.5ms
# Speed: 0.7ms preprocess, 32.5ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='/content/runs/classify/train/weights/best.pt' source='/content/Cancer-Types-1/test/normal/22_png.rf.b0cb22f05e4f20b12a84f65f018b1606.jpg'
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m-cls summary (fused): 103 layers, 15767780 parameters, 0 gradients, 41.6 GFLOPs
#
# image 1/1 /content/Cancer-Types-1/test/normal/22_png.rf.b0cb22f05e4f20b12a84f65f018b1606.jpg: 64x64 adenocarcinoma 0.92, large cell carcinoma 0.05, squamous cell carcinoma 0.02, normal 0.01, 33.3ms
# Speed: 0.8ms preprocess, 33.3ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
